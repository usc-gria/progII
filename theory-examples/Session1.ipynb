# %% [markdown]
# # Sesión 1 - Ejemplos de clase

# %%
my_dict = {
	"temperature": 25,
	"location": "Living Room",
	"datetime": "2023-09-18T00:00:01"
}

#print(my_dict["temperatura"])
if my_dict.get("temperatura"):
    print(my_dict["temperatura"])
else:
    print("hello")
# Out:
# hello

# %%
my_dict = {
	"temperature": 25,
	"location": "Living Room",
	"datetime": "2023-09-18T00:00:01"
}


my_dict["temperatura"] = 30
my_dict["name"] ="my iot system"

print(my_dict)
# Out:
# {'temperature': 25, 'location': 'Living Room', 'datetime': '2023-09-18T00:00:01', 'temperatura': 30, 'name': 'my iot system'}

# %%
my_dict = {
	"temperature": [25, 30, 50],
	"location": "Living Room",
	"datetime": "2023-09-18T00:00:01"
}

for t in my_dict["temperature"]:
    print(f"Temperatura {t}")
# Out:
# Temperatura 25
# Temperatura 30
# Temperatura 50

# %%
my_dict = {
	"temperature": [25, 30, 50],
	"location": "Living Room",
	"datetime": "2023-09-18T00:00:01"
}

print(type(my_dict.keys()))

for k in list(my_dict.keys()):
    print(k, my_dict[k])
# Out:
# <class 'dict_keys'>
# temperature [25, 30, 50]
# location Living Room
# datetime 2023-09-18T00:00:01

# %%
file1 = open("./test/archivo.txt")



# read the file

read_content = file1.readlines()
print(read_content)
file1.close()

for i in read_content:
    read
# Out:
# ['hola\n', 'que tal\n', 'adios\n']

# %%
import csv
data = [ ["nombre", "edad", "ciudad"], ["Ana", 25, "Madrid"], ["Luis", 30, "Barcelona"],["Marta", 28, "Valencia"]  ]

with open("people.csv", mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
import csv

with open("data.csv", mode="r", encoding="utf-8") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['titulo', 'artista', 'album', 'duracion', 'popularidad']
# ["Don't Stop Believin' (2024 Remaster)", 'Journey', 'Greatest Hits (2024 Remaster)', '250', '16']
# ['Rockstar', 'Nickelback', 'All the Right Reasons', '255', '11']
# ["I'm Yours", 'Jason Mraz', 'We Sing. We Dance. We Steal Things', '242', '12']
# ['Just Give Me a Reason (feat. Nate Ruess)', 'P!nk', 'The Truth About Love', '242', '15']
# ['Pumped Up Kicks', 'Foster the People', 'Torches', '239', '11']
# ['When I Was Your Man', 'Bruno Mars', 'Unorthodox Jukebox', '213', '10']
# ['Sail', 'AWOLNATION', 'Megalithic Symphony', '259', '15']
# ['What Makes You Beautiful', 'One Direction', 'Up All Night (Deluxe Version)', '199', '15']
# ['Locked Out of Heaven', 'Bruno Mars', 'Unorthodox Jukebox', '233', '10']
# ["Stronger (What Doesn't Kill You)", 'Kelly Clarkson', 'Stronger (Deluxe Version)', '221', '18']
# ['Lights (2024 Remaster)', 'Journey', 'Greatest Hits (2024 Remaster)', '190', '16']
# ...
